# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("marketing_customer_analysis.csv")

# %%
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income     ...       \
# 0           2/24/11         Employed      F   56274     ...
# 1           1/31/11       Unemployed      F       0     ...
# 2           2/19/11         Employed      F   48767     ...
# 3           1/20/11       Unemployed      M       0     ...
# 4            2/3/11         Employed      M   43836     ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
# Customer                         9134 non-null object
# State                            9134 non-null object
# Customer Lifetime Value          9134 non-null float64
# Response                         9134 non-null object
# Coverage                         9134 non-null object
# Education                        9134 non-null object
# Effective To Date                9134 non-null object
# EmploymentStatus                 9134 non-null object
# Gender                           9134 non-null object
# Income                           9134 non-null int64
# Location Code                    9134 non-null object
# Marital Status                   9134 non-null object
# Monthly Premium Auto             9134 non-null int64
# Months Since Last Claim          9134 non-null int64
# Months Since Policy Inception    9134 non-null int64
# ...

# %%
num_data = data.select_dtypes(include = "number")

# %%
num_data.head()
# Out:
#    Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    Number of Open Complaints  Number of Policies  Total Claim Amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %%
#Check Normality
from scipy.stats import skew
num_data.apply(skew)
# Out:
# Customer Lifetime Value          3.031782
# Income                           0.286840
# Monthly Premium Auto             2.123198
# Months Since Last Claim          0.278541
# Months Since Policy Inception    0.040158
# Number of Open Complaints        2.782806
# Number of Policies               1.253127
# Total Claim Amount               1.714684
# dtype: float64

# %%
from scipy.stats import kurtosis
kurtosis(num_data)
# Out:
# array([13.8153107 , -1.09438383,  6.18955826, -1.07373684, -1.13308258,
#         7.7444103 ,  0.36230101,  5.97547158])

# %%
from statsmodels.graphics.gofplots import qqplot
num_cols = list (num_data.columns)
for col in num_cols:
    print ("Q-Q plot for variable: ", col)
    fig, ax = plt.subplots(1,1)
    ax = qqplot(data[col], line = 's')
    plt.show()
    print ("Boxplot for variable: ", col)
    fig, bx = plt.subplots(1,1)
    bx = data.boxplot(column = col)
    plt.show()
    print ("Distplot for variable: ", col)
    fig, cs = plt.subplots (1,1)
    cx = sns.distplot(data[col])
    plt.show()
# Out:
# Q-Q plot for variable:  Customer Lifetime Value
# Boxplot for variable:  Customer Lifetime Value
# Distplot for variable:  Customer Lifetime Value
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Q-Q plot for variable:  Income
# Boxplot for variable:  Income
# Distplot for variable:  Income
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Q-Q plot for variable:  Monthly Premium Auto
# Boxplot for variable:  Monthly Premium Auto
# Distplot for variable:  Monthly Premium Auto
# ...

# %%
sns.pairplot(num_data)

# %%
pearson_corr = num_data.corr()
kendall_corr = num_data.corr(method = "kendall")
spearman_corr = num_data.corr(method = "spearman")

fig, dx = plt.subplots(figsize = (10,8))
ax = sns.heatmap(pearson_corr, annot = True)
plt.show()

fig, ex = plt.subplots(figsize = (10,8))
ax = sns.heatmap(kendall_corr, annot = True)
plt.show()

fig, fx = plt.subplots(figsize = (10,8))
ax = sns.heatmap(spearman_corr, annot = True)
plt.show()

# %%
y = num_data["Total Claim Amount"]
x = num_data.drop("Total Claim Amount", axis = 1)

# %%
from sklearn.preprocessing import Normalizer
transformer = Normalizer().fit(x)
x_normalized = transformer.transform(x)

# %%
df_norm = pd.DataFrame(x_normalized)

# %%
c = list(x.columns)
df_norm.columns = [c]
df_norm = pd.concat([df_norm,data["Total Claim Amount"]], axis = 1)
df_norm.head()

# %%
str_data = data.select_dtypes(include = "object")
str_data = str_data.drop(columns = "Customer")
for col in str_data.columns:
    print("Dummification of the col: ",col)
    print(pd.get_dummies(str_data[col], drop_first = True))

# %%
df_norm.head()

# %%
for col in str_data.columns:
    dummy = pd.get_dummies(str_data[col], drop_first = True)
    df_norm = pd.concat([df_norm,dummy], axis = 1)
df_norm.head()

# %%
#encoder = OneHotEncoder(handle_unknown='error', drop = "first").fit(data[["gender"]])
#encoded = encoder.transform(data[["gender"]]).toarray()
#encoded

# %%
# Test Split
Y = df_norm["Total Claim Amount"]
X = df_norm.drop(columns = "Total Claim Amount")
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.3, random_state = 100)

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
lm = linear_model.LinearRegression()
model = lm.fit(X_train, Y_train)
lm.score(X,Y)
print ("lm intercept: ", lm.intercept_)
print ("lm coeff: ", lm.coef_)
predictions = lm.predict(X)
mse = mean_squared_error(Y,predictions)
print ("mse is: ", mse)
rmse = sqrt(mse)
print ("rmse is: ", rmse)
r2 = r2_score(Y,predictions)
print ("r2 is: ", r2)

# %%
#### Stats Model
import statsmodels.api as sm
from statsmodels.formula.api import ols
Y = data2["median_home_val"]
X = data2.drop(["median_home_val"], axis = 1)
X = sm.add_constant(X)
model = sm.OLS(Y,X).fit()
print (model.summary())
